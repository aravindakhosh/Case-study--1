# %%
# importing pandas to use as pd ,matplotlib.pyplot as plt and seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# read the the given data set  from file location
data = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\corse detail\Case study due 16th\cars_data.csv")
data.columns
# Out:
# Index(['Make', 'Model', 'Nickname', 'Car Gender', 'Buyer Gender', 'Buyer Age',
#        'Buzzword', 'Country', 'City', 'Dealer Latitude', 'Dealer Longitude',
#        'Color', 'New Car', 'Purchase Date', 'Sale Price', 'Discount',
#        'Resell Price', '5-yr Depreciation', 'Top Speed', '0-60 Time'],
#       dtype='object')

# %%
# find the null values 
data.isnull()
# Out:
#        Make  Model  Nickname  Car Gender  Buyer Gender  Buyer Age  Buzzword  \
# 0     False  False     False       False         False      False     False
# 1     False  False     False       False         False      False     False
# 2     False  False     False       False         False      False     False
# 3     False  False     False       False         False      False     False
# 4     False  False     False       False         False      False     False
# ...     ...    ...       ...         ...           ...        ...       ...
# 9995  False  False     False       False         False      False     False
# 9996  False  False     False       False         False      False     False
# 9997  False  False     False       False         False      False     False
# 9998  False  False     False       False         False      False     False
# 9999  False  False     False       False         False      False     False
#
# ...

# %%
data.isnull().sum()
# Out:
# Make                 0
# Model                0
# Nickname             0
# Car Gender           0
# Buyer Gender         0
# Buyer Age            0
# Buzzword             0
# Country              0
# City                 0
# Dealer Latitude      0
# Dealer Longitude     0
# Color                0
# New Car              0
# Purchase Date        0
# Sale Price           0
# Discount             0
# Resell Price         0
# 5-yr Depreciation    0
# Top Speed            0
# 0-60 Time            0
# dtype: int64

# %%
# to find  the top 5 cars based on their sales price.
data.nlargest(5, 'Sale Price', keep='last')
# Out:
#             Make      Model   Nickname Car Gender Buyer Gender  Buyer Age  \
# 5984  Volkswagen  Jetta III    Rachael     Female       Female         73
# 1270        Audi         A6      Thorn       Male         Male         75
# 3460       Lexus         LX      Aldin     Female         Male         38
# 9032       Mazda       MX-6  Sylvester     Female         Male         26
# 302        Lexus         ES       Brig     Female         Male         39
#
#                Buzzword   Country           City  Dealer Latitude  \
# 5984               core    Russia    Krasnoyarka        59.418208
# 1270           function    Latvia        Līgatne        57.236340
# 3460           software  Malaysia      Pasir Mas         6.109065
# 9032  internet solution    Russia  Krutaya Gorka        55.369917
# 302         user-facing    Canada       Langford        48.447463
#
#       Dealer Longitude   Color  New Car Purchase Date  Sale Price  Discount  \
# ...

# %%
# Find the least 5 cars based on their Resell price.
data.nsmallest(5, 'Resell Price', keep='last')
# Out:
#             Make        Model Nickname Car Gender Buyer Gender  Buyer Age  \
# 2446   Chevrolet         1500  Corenda       Male       Female         25
# 4933         GMC  Savana 1500     Lark     Female       Female         34
# 566       Jaguar           XF   Payton     Female         Male         64
# 2538  Mitsubishi       3000GT     Thia     Female       Female         25
# 5869    Infiniti          G37    Sonny       Male         Male         20
#
#             Buzzword      Country              City  Dealer Latitude  \
# 2446   collaboration  Philippines           Tubigan         8.490877
# 4933     interactive       Poland       Śródmieście        53.838651
# 566        Visionary      Nigeria       Ikot-Ekpene         5.174447
# 2538  well-modulated        China        Yanweigang        34.509325
# 5869      optimizing       France  Clermont-Ferrand        45.786764
#
#       Dealer Longitude      Color  New Car Purchase Date  Sale Price  \
# ...

# %%
male  = data.loc[data['Buyer Gender'] == 'Male']
female  = data.loc[data['Buyer Gender'] == 'Female']

# %%
male
# Out:
#           Make           Model  Nickname Car Gender Buyer Gender  Buyer Age  \
# 1        Honda           S2000    Henrik       Male         Male         30
# 3       Toyota          Tacoma  Jefferey     Female         Male         68
# 4         Ford         Festiva   Glendon     Female         Male         70
# 6     Infiniti              QX       Bud       Male         Male         66
# 7          Ram             C/V  Geoffrey     Female         Male         37
# ...        ...             ...       ...        ...          ...        ...
# 9993      Ford  Econoline E350     Bruis     Female         Male         68
# 9995     Mazda         Tribute    Cooper       Male         Male         44
# 9996       GMC     Sierra 2500       Dud       Male         Male         40
# 9997   Mercury         Mariner   Chariot       Male         Male         37
# 9999    Toyota         Sequoia  Zedekiah     Female         Male         21
#
# ...

# %%
# To Plot a bar graph of male and female buyers participated in the sales.
s = data['Buyer Gender'].value_counts()

# %%
s
# Out:
# Female    5052
# Male      4948
# Name: Buyer Gender, dtype: int64

# %%
s.plot(kind='bar',color = 'r' )
plt.xlabel('Buyer Gender')
plt.ylabel('Count in number')
plt.title(' SALES DATA')
plt.grid(True, linewidth= 1, linestyle="--")
plt.title('Females and Males Participated in sales')
plt.show()
